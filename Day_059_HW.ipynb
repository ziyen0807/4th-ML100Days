# %% [markdown]
# # 作業
# ### 用 digits (3個數字即可 , dataset.load_digits(n_class=3)) 資料嘗試跑 PCA

# %%
from sklearn import datasets
import matplotlib.pyplot as plt
digits = datasets.load_digits(n_class=3)
X = digits.data
y = digits.target

data_num = 10
for index,image in enumerate(digits.images[:data_num]):
    plt.subplot(2,5,index+1)
    plt.title(y[index])
    plt.imshow(image,cmap = plt.cm.gray_r)

# %%
from sklearn import decomposition
pca = decomposition.PCA(n_components = 36)
decomposition_x = pca.fit_transform(X)
X_temp = np.reshape(X[:,:,np.newaxis],(X.shape[0],8,8))
decomposition_image = np.reshape(decomposition_x[:,:,np.newaxis],(decomposition_x.shape[0],6,6))

for index,image in enumerate(decomposition_image[:10]):
    plt.subplot(2,5,index+1)
    plt.title(y[index])
    plt.imshow(image,cmap = plt.cm.gray_r)

# %% [markdown]
# 載入 相關套件 並 執行 PCA 實驗 ...

# %%
from sklearn import decomposition
import numpy as np
import matplotlib.pyplot as plt
pca = decomposition.PCA(n_components = 1)

arr = np.random.randn(20,2).round(1)
arr2 = pca.fit_transform(arr)
plt.subplot(1,2,1)
plt.scatter(arr[:,0],arr[:,1])
plt.subplot(1,2,2)
plt.plot(arr2)
for index,value in enumerate(arr2):
    print(f"index {index} , arr1 {arr[index]}, arr2 {value}")
#plt.scatter(arr2[:,0],arr2[:,1])
# Out:
# index 0 , arr1 [1.1 0.9], arr2 [0.61956778]
# index 1 , arr1 [1.6 1. ], arr2 [0.54311335]
# index 2 , arr1 [-1.3 -0.8], arr2 [-0.16036052]
# index 3 , arr1 [0.9 1.2], arr2 [0.9697801]
# index 4 , arr1 [-1.9  0.7], arr2 [1.45433033]
# index 5 , arr1 [-0.  -1.1], arr2 [-0.88559236]
# index 6 , arr1 [-0.3  0.6], arr2 [0.81483841]
# index 7 , arr1 [0.4 0.7], arr2 [0.6701986]
# index 8 , arr1 [0.7 1.8], arr2 [1.60201937]
# index 9 , arr1 [0.2 0.4], arr2 [0.45635702]
# index 10 , arr1 [ 0.  -0.8], arr2 [-0.60356541]
# index 11 , arr1 [ 0.9 -1.2], arr2 [-1.2864355]
# index 12 , arr1 [ 0.2 -2. ], arr2 [-1.79985857]
# index 13 , arr1 [0.5 0.3], arr2 [0.26006999]
# index 14 , arr1 [-0.7  2.1], arr2 [2.36134389]
# index 15 , arr1 [-0.1 -0.7], arr2 [-0.47546374]
# index 16 , arr1 [ 1.3 -2.1], arr2 [-2.26888708]
# index 17 , arr1 [ 1.4 -2. ], arr2 [-2.20897078]
# index 18 , arr1 [ 1.1 -0.9], arr2 [-1.07259391]
# index 19 , arr1 [-1.7  0.3], arr2 [1.01010903]
